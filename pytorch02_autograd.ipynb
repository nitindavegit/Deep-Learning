# %% [markdown]
# <a href="https://colab.research.google.com/github/nitindavegit/Deep-Learning/blob/main/pytorch02_autograd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def dx_dy(x):
  return 2*x

# %%
print(dx_dy(3))
# Out:
# 6

# %%
import math
def dz_dx(x):
  return 2 * x * math.cos(x ** 2)

# %%
dz_dx(5)
# Out:
# 9.912028118634735

# %%
import torch

# %%
torch.tensor([1,2,3])
# Out:
# tensor([1, 2, 3])

# %%
torch.tensor(1)
# Out:
# tensor(1)

# %%
torch.tensor([1])
# Out:
# tensor([1])

# %%
x = torch.tensor(3.00, requires_grad=True)

# %%
y = x ** 2

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(6.)

# %%
x = torch.tensor(3.0, requires_grad=True)

# %%
y = x ** 2

# %%
z = torch.sin(y)

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
z
# Out:
# tensor(0.4121, grad_fn=<SinBackward0>)

# %%
z.backward()

# %%
x.grad
# Out:
# tensor(-5.4668)

# %% [markdown]
# # ***Example***

# %%
import torch
x = torch.tensor(6.7)  # input
y = torch.tensor(0.0)  # real answer

w = torch.tensor(1.0) # weight
b = torch.tensor(0.0) # bias

# %%
# Binary cross entropy loss for scalar
def binary_cross_entropy_loss(prediction, target):
  epsilon = 1e-8
  prediction = torch.clamp(prediction, epsilon,1 - epsilon )
  return - (target * torch.log(prediction) + (1 - target) * torch.log(1 - prediction))

# %%
# Forward pass
z = w * x + b
y_pred = torch.sigmoid(z)

# compute loss
loss = binary_cross_entropy_loss(y_pred,y)

# %%
# all derivatives
dloss_dy_pred = (y_pred - y) / (y_pred * (1 - y_pred))
dy_pred_dz = y_pred * (1 - y_pred)
dz_dw = x
dz_db = 1
dL_dw = dloss_dy_pred * dy_pred_dz * dz_dw
dL_db = dloss_dy_pred * dy_pred_dz * dz_db

# %%
print(f"Manual gradient of loss w.r.t. weight : {dL_dw}")
print(f"Manual gradient of loss w.r.t. bias : {dL_db}")
# Out:
# Manual gradient of loss w.r.t. weight : 6.691762447357178
# Manual gradient of loss w.r.t. bias : 0.998770534992218

# %% [markdown]
# ## **`*Mentos zindagi*`**

# %%
x = torch.tensor(6.7)
y = torch.tensor(0.0)

# %%
w = torch.tensor(1.0,requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)

# %%
z = w*x + b
z
# Out:
# tensor(6.7000, grad_fn=<AddBackward0>)

# %%
y_pred = torch.sigmoid(z)
y_pred
# Out:
# tensor(0.9988, grad_fn=<SigmoidBackward0>)

# %%
loss = binary_cross_entropy_loss(y_pred, y)
loss
# Out:
# tensor(6.7012, grad_fn=<NegBackward0>)

# %%
loss.backward()

# %%
print(w.grad)
print(b.grad)
# Out:
# tensor(6.6918)
# tensor(0.9988)

# %% [markdown]
# ## ***Using Vector inputs***

# %%
x = torch.tensor([1.0,2.0,3.0], requires_grad=True)
x
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %%
y = (x ** 3).median()
y
# Out:
# tensor(8., grad_fn=<MedianBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor([ 0., 12.,  0.])

# %% [markdown]
# # Clearing Grad

# %%
x.grad.zero_()
# Out:
# tensor([0., 0., 0.])

# %% [markdown]
# *How to disable gradient tracking*

# %%
# option 1
x.requires_grad_(False)
# Out:
# tensor([1., 2., 3.])

# %%
# option 2
z = x.detach()

# %%
# option 3
with torch.no_grad():
  y = x ** 2
